# %%
import os

# %%
# %pwd
# Out:
# '/home/labhhc5/Documents/workspace/D20/HHuy/HaMy'

# %%
# !wget https://downloads.sourceforge.net/project/smina/smina.static
# Out:
# --2022-09-21 00:26:24--  https://downloads.sourceforge.net/project/smina/smina.static
# Resolving downloads.sourceforge.net (downloads.sourceforge.net)... 204.68.111.105
# Connecting to downloads.sourceforge.net (downloads.sourceforge.net)|204.68.111.105|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://onboardcloud.dl.sourceforge.net/project/smina/smina.static [following]
# --2022-09-21 00:26:24--  https://onboardcloud.dl.sourceforge.net/project/smina/smina.static
# Resolving onboardcloud.dl.sourceforge.net (onboardcloud.dl.sourceforge.net)... 202.79.184.253
# Connecting to onboardcloud.dl.sourceforge.net (onboardcloud.dl.sourceforge.net)|202.79.184.253|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9853920 (9,4M) [application/octet-stream]
# Saving to: ‘smina.static’
#
# smina.static        100%[===================>]   9,40M  5,55MB/s    in 1,7s
#
# ...

# %%
# !chmod +x smina.static

# %%
# !./smina.static --help
# Out:
# Input:
#   -r [ --receptor ] arg         rigid part of the receptor (PDBQT)
#   --flex arg                    flexible side chains, if any (PDBQT)
#   -l [ --ligand ] arg           ligand(s)
#   --flexres arg                 flexible side chains specified by comma
#                                 separated list of chain:resid or
#                                 chain:resid:icode
#   --flexdist_ligand arg         Ligand to use for flexdist
#   --flexdist arg                set all side chains within specified distance
#                                 to flexdist_ligand to flexible
#
# Search space (required):
#   --center_x arg                X coordinate of the center
#   --center_y arg                Y coordinate of the center
#   --center_z arg                Z coordinate of the center
#   --size_x arg                  size in the X dimension (Angstroms)
#   --size_y arg                  size in the Y dimension (Angstroms)
# ...

# %%
import glob
import os
os.chdir("/home/labhhc5/Documents/workspace/D20/HHuy/HaMy/Decoy_1")
ligand_dir = str(os.getcwd())
ligand_name = []
for i in sorted(glob.glob("/home/labhhc5/Documents/workspace/D20/HHuy/HaMy/Decoy_1/*.pdbqt")):
  ligand_name.append(i[len(ligand_dir)+1:-6])

os.chdir('/home/labhhc5/Documents/workspace/D20/HHuy/HaMy')
for i in ligand_name:
    # !./smina.static --receptor "/home/labhhc5/Documents/workspace/D20/HHuy/HaMy/Protein/6njs.pdbqt" --ligand "/home/labhhc5/Documents/workspace/D20/HHuy/HaMy/Decoy_1/{i}.pdbqt" --center_x 12.599 --center_y 54.028 --center_z 1.242 --size_x 25 --size_z 25 --size_y 25 --cpu 24 -o /home/labhhc5/Documents/workspace/D20/HHuy/HaMy/Result/Raw_result/{i}.pdbqt --seed 42 --exhaustiveness 4 --num_modes 100 > /home/labhhc5/Documents/workspace/D20/HHuy/HaMy/Log/{i}.txt

# %%
import glob
import os
os.chdir("/home/labhhc/Documents/MyD17/Qvina/Decoy_2")
ligand_dir = str(os.getcwd())
ligand_name = []
for i in sorted(glob.glob("/home/labhhc/Documents/MyD17/Qvina/Decoy_2/*.pdbqt")):
  ligand_name.append(i[len(ligand_dir)+1:-6])

os.chdir('/home/labhhc/Documents/MyD17/Smina')
for i in ligand_name:
    # !./smina.static --receptor "/home/labhhc/Documents/MyD17/Protein/6njs.pdbqt" --ligand "/home/labhhc/Documents/MyD17/Qvina/Decoy_2/{i}.pdbqt" --center_x 12.599 --center_y 54.028 --center_z 1.242 --size_x 25 --size_z 25 --size_y 25 --cpu 24 --out /home/labhhc/Documents/MyD17/Smina/Result/Raw_result/{i}.pdbqt --seed 42 --exhaustiveness 150 --num_modes 100 > /home/labhhc/Documents/MyD17/Smina/Log/{i}.txt

# %%
import glob
import os
os.chdir("/home/labhhc/Documents/MyD17/Qvina/Decoy_3")
ligand_dir = str(os.getcwd())
ligand_name = []
for i in sorted(glob.glob("/home/labhhc/Documents/MyD17/Qvina/Decoy_3/*.pdbqt")):
  ligand_name.append(i[len(ligand_dir)+1:-6])

os.chdir('/home/labhhc/Documents/MyD17/Smina')
for i in ligand_name:
    # !./smina.static --receptor "/home/labhhc/Documents/MyD17/Protein/6njs.pdbqt" --ligand "/home/labhhc/Documents/MyD17/Qvina/Decoy_3/{i}.pdbqt" --center_x 12.599 --center_y 54.028 --center_z 1.242 --size_x 25 --size_z 25 --size_y 25 --cpu 24 --out /home/labhhc/Documents/MyD17/Smina/Result/Raw_result/{i}.pdbqt --seed 42 --exhaustiveness 150 --num_modes 100 > /home/labhhc/Documents/MyD17/Smina/Log/{i}.txt

# %%
import glob
import os
os.chdir("/home/labhhc/Documents/MyD17/Qvina/Active")
ligand_dir = str(os.getcwd())
ligand_name = []
for i in sorted(glob.glob("/home/labhhc/Documents/MyD17/Qvina/Active/*.pdbqt")):
  ligand_name.append(i[len(ligand_dir)+1:-6])

os.chdir('/home/labhhc/Documents/MyD17/Smina')
for i in ligand_name:
    # !./smina.static --receptor "/home/labhhc/Documents/MyD17/Protein/6njs.pdbqt" --ligand "/home/labhhc/Documents/MyD17/Qvina/Active/{i}.pdbqt" --center_x 12.599 --center_y 54.028 --center_z 1.242 --size_x 25 --size_z 25 --size_y 25 --cpu 24 --out /home/labhhc/Documents/MyD17/Smina/Result/Raw_result/{i}.pdbqt --seed 42 --exhaustiveness 150 --num_modes 100 > /home/labhhc/Documents/MyD17/Smina/Log/{i}.txt

# %%
# Out:
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_1.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_10.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_100.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_101.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_102.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_103.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_104.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_105.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_106.pdbqt" for writing.
#
#
# ...

# %%
import glob
import os
os.chdir("/home/labhhc/Documents/MyD17/Qvina/Decoy_2")
ligand_dir = str(os.getcwd())
ligand_name = []
for i in sorted(glob.glob("/home/labhhc/Documents/MyD17/Qvina/Decoy_2/*.pdbqt")):
  ligand_name.append(i[len(ligand_dir)+1:-6])

os.chdir('/home/labhhc/Documents/MyD17/Smina')
for i in ligand_name:
    # !./smina.static --receptor "/home/labhhc/Documents/MyD17/Protein/6njs.pdbqt" --ligand "/home/labhhc/Documents/MyD17/Qvina/Decoy_2/{i}.pdbqt" --center_x 12.599 --center_y 54.028 --center_z 1.242 --size_x 25 --size_z 25 --size_y 25 --cpu 24 --out /home/labhhc/Documents/MyD17/Smina/Result/Raw_result/{i}.pdbqt --seed 42 --exhaustiveness 150 --num_modes 100 > /home/labhhc/Documents/MyD17/Smina/Log/{i}.txt
# Out:
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_401.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_402.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_403.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_404.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_405.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_406.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_407.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_408.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/dude_409.pdbqt" for writing.
#
#
# ...

# %%
import glob
import os
os.chdir("/home/labhhc/Documents/MyD17/Qvina/Decoy_3")
ligand_dir = str(os.getcwd())
ligand_name = []
for i in sorted(glob.glob("/home/labhhc/Documents/MyD17/Qvina/Decoy_3/*.pdbqt")):
  ligand_name.append(i[len(ligand_dir)+1:-6])

os.chdir('/home/labhhc/Documents/MyD17/Smina')
for i in ligand_name:
    # !./smina.static --receptor "/home/labhhc/Documents/MyD17/Protein/6njs.pdbqt" --ligand "/home/labhhc/Documents/MyD17/Qvina/Decoy_3/{i}.pdbqt" --center_x 12.599 --center_y 54.028 --center_z 1.242 --size_x 25 --size_z 25 --size_y 25 --cpu 24 --out /home/labhhc/Documents/MyD17/Smina/Result1/Raw_result/{i}.pdbqt --seed 42 --exhaustiveness 150 --num_modes 100 > /home/labhhc/Documents/MyD17/Smina/Log1/{i}.txt

# %%
import glob
import os
os.chdir("/home/labhhc/Documents/MyD17/Qvina/Active")
ligand_dir = str(os.getcwd())
ligand_name = []
for i in sorted(glob.glob("/home/labhhc/Documents/MyD17/Qvina/Active/*.pdbqt")):
  ligand_name.append(i[len(ligand_dir)+1:-6])

os.chdir('/home/labhhc/Documents/MyD17/Smina')
for i in ligand_name:
    # !./smina.static --receptor "/home/labhhc/Documents/MyD17/Protein/6njs.pdbqt" --ligand "/home/labhhc/Documents/MyD17/Qvina/Active/{i}.pdbqt" --center_x 12.599 --center_y 54.028 --center_z 1.242 --size_x 25 --size_z 25 --size_y 25 --cpu 24 --out /home/labhhc/Documents/MyD17/Smina/Result/Raw_result/{i}.pdbqt --seed 42 --exhaustiveness 150 --num_modes 100 > /home/labhhc/Documents/MyD17/Smina/Log/{i}.txt
# Out:
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/ligand1.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/ligand10.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/ligand11.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/ligand12.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/ligand13.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/ligand14.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/ligand15.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/ligand16.pdbqt" for writing.
#
#
# Error: could not open "/home/labhhc/Documents/MyD17/Smina/Result/Raw_result/ligand17.pdbqt" for writing.
#
#
# ...

# %%
import glob
import os
os.chdir("/home/labhhc/Documents/Bao_Vy/Docking/6puw_smina/Decoy_3")
ligand_dir = str(os.getcwd())
ligand_name = []
for i in sorted(glob.glob("/home/labhhc/Documents/Bao_Vy/Docking/6puw_smina/Decoy_3/*.pdbqt")):
  ligand_name.append(i[len(ligand_dir)+1:-6])
os.chdir('/home/labhhc/Documents/Bao_Vy/Docking/6puw_smina')

# %%
os.chdir('/home/labhhc/Documents/Bao_Vy/Docking')
for i in ligand_name:
    # !./smina.static --receptor "/home/labhhc/Documents/Bao_Vy/Docking/6puw_smina/Protein/6puw_protein.pdbqt" --ligand "/home/labhhc/Documents/Bao_Vy/Docking/6puw_smina/Decoy_3/{i}.pdbqt" --center_x 143.399 --center_y 159.402 --center_z 177.382 --size_x 60 --size_z 60 --size_y 60 --cpu 24 --out /home/labhhc/Documents/Bao_Vy/Docking/6puw_smina/Result/Raw_result/{i}.pdbqt --seed 42 --exhaustiveness 100 --num_modes 1000 > /home/labhhc/Documents/Bao_Vy/Docking/6puw_smina/Log/{i}.txt

# %%
import glob
import os
os.chdir("/home/labhhc/Documents/Bao_Vy/Docking/6puw_smina/Decoy_4")
ligand_dir = str(os.getcwd())
ligand_name = []
for i in sorted(glob.glob("/home/labhhc/Documents/Bao_Vy/Docking/6puw_smina/Decoy_4/*.pdbqt")):
  ligand_name.append(i[len(ligand_dir)+1:-6])
os.chdir('/home/labhhc/Documents/Bao_Vy/Docking/6puw_smina')

# %%
os.chdir('/home/labhhc/Documents/Bao_Vy/Docking')
for i in ligand_name:
    # !./smina.static --receptor "/home/labhhc/Documents/Bao_Vy/Docking/6puw_smina/Protein/6puw_protein.pdbqt" --ligand "/home/labhhc/Documents/Bao_Vy/Docking/6puw_smina/Decoy_4/{i}.pdbqt" --center_x 143.399 --center_y 159.402 --center_z 177.382 --size_x 60 --size_z 60 --size_y 60 --cpu 24 --out /home/labhhc/Documents/Bao_Vy/Docking/6puw_smina/Result/Raw_result/{i}.pdbqt --seed 42 --exhaustiveness 100 --num_modes 1000 > /home/labhhc/Documents/Bao_Vy/Docking/6puw_smina/Log/{i}.txt

# %%
os.chdir('/home/labhhc/Documents/Bao_Vy/Docking')
# !./smina.static
# Out:
# Missing receptor.
#
# Correct usage:
#
# Input:
#   -r [ --receptor ] arg         rigid part of the receptor (PDBQT)
#   --flex arg                    flexible side chains, if any (PDBQT)
#   -l [ --ligand ] arg           ligand(s)
#   --flexres arg                 flexible side chains specified by comma
#                                 separated list of chain:resid or
#                                 chain:resid:icode
#   --flexdist_ligand arg         Ligand to use for flexdist
#   --flexdist arg                set all side chains within specified distance
#                                 to flexdist_ligand to flexible
#
# Search space (required):
#   --center_x arg                X coordinate of the center
#   --center_y arg                Y coordinate of the center
#   --center_z arg                Z coordinate of the center
#   --size_x arg                  size in the X dimension (Angstroms)
#   --size_y arg                  size in the Y dimension (Angstroms)
# ...
