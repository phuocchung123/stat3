# %%
import pandas as pd

df = pd.read_csv('QHuy_HD.csv')
print(df.columns)
df.head(2)
# Out:
# Index(['Smiles', 'MW', 'LogP', 'HBA', 'HBD', 'PSA', 'Fsp3', 'SA', 'MCE18',
#        'NP_Score', 'Lipinski_Pass', 'Pfizer_pass', 'Fsp3_pass', 'MCE_pass',
#        'SA_pass', 'NP_pass', 'Final_pass', 'PAINS', 'BMS', 'CHE'],
#       dtype='object')
#                                               Smiles       MW    LogP  HBA  \
# 0  CC(=O)OC(C)(C)/C=C/[C@@H](NCC(=O)O)[C@](C)(O)[...  617.780  3.4557    9
# 1  CCC(=O)OC(C)(C)/C=C/[C@@H](NCC(=O)O)[C@](C)(O)...  631.807  3.8458    9
#
#    HBD     PSA      Fsp3        SA  MCE18            NP_Score  Lipinski_Pass  \
# 0    6  173.62  0.735294  5.768196     48  2.4754670632987685          False
# 1    6  173.62  0.742857  5.806449     48  2.3105337131543955          False
#
#    Pfizer_pass  Fsp3_pass  MCE_pass  SA_pass  NP_pass  Final_pass  PAINS  \
# 0         True       True      True     True     True       False   True
# 1         True       True      True     True     True       False   True
#
#     BMS   CHE
# 0  True  True
# ...

# %%
li_filter = df[df['Lipinski_Pass']==True]
li_filter.shape
# Out:
# (88, 20)

# %%
li_filter[(li_filter['BMS']==True) & (li_filter['PAINS'] == True) & (li_filter['CHE'] == True) & (li_filter['Fsp3_pass']==True) & (li_filter['MCE_pass']==True) & (li_filter['SA_pass']==True)& (li_filter['Pfizer_pass']==True)].shape
# Out:
# (85, 20)
